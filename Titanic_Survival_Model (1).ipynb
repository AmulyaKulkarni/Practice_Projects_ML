# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
titanic = pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Age'].fillna(titanic['Age'].median(), inplace=True)
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis

# %%
sb.countplot(x='Survived', hue='Sex',data=titanic, palette='colorblind')
plt.xlabel('Survived')
plt.ylabel('Gender')
plt.title('Count of Survivors by Gender')
plt.show()

# %%
sb.barplot(x='Embarked', y='Survived', data=titanic, palette='colorblind')
plt.xlabel('Survived')
plt.ylabel('Embarked')
plt.title('Count of Survivors by Embarked Status')
plt.show()

# %%
sb.boxplot(x='Survived', y='Age', data=titanic, palette='colorblind')
plt.xlabel('Survived')
plt.ylabel('Age')
plt.title('Count of Survivors by Age')
plt.show()

# %%
sb.heatmap(titanic.corr(), annot=True, cmap='BrBG')
plt.title('Heatmap of the data')
plt.show()

# %%
#Distribution of Features

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sb.histplot(titanic['Age'].dropna(),kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribution of Age')

plt.subplot(1,2,2)
sb.histplot(titanic['Fare'].dropna(),kde=True)
plt.xlabel('Fare')
plt.ylabel('Count')
plt.title('Distribution of Fare')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sb.countplot(x='Pclass', hue='Survived', data=titanic, palette='colorblind')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.title('Survival Count by Passenger Class')

plt.subplot(1,2,2)
sb.countplot(x='Embarked', hue='Survived', data=titanic, palette='colorblind')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.title('Survival COunt by Embarked')

plt.tight_layout()
plt.show()

# %%
titanic['FamilySize'] = titanic['SibSp'] + titanic['Parch'] + 1
plt.figure(figsize=(8,4))
sb.countplot(x='FamilySize', hue='Survived', data=titanic, palette='colorblind')
plt.xlabel('Family Size')
plt.ylabel('Count')
plt.title('Survival Count by Family Size')
plt.show()

# %%
plt.figure(figsize=(8,4))
sb.boxplot(x='Pclass', y='Fare', data=titanic)
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.title('Fare Distribution by Passenger Class')
plt.show()

# %%
sb.pairplot(titanic)

# %% [markdown]
# Data Preprocessing and Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
e = LabelEncoder()
sc = StandardScaler()
titanic['Sex'] = e.fit_transform(titanic['Sex'])
titanic['Embarked'] = e.fit_transform(titanic['Embarked'])

# %%
titanic['FamilySize'] = titanic['SibSp'] + titanic['Parch'] + 1
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  FamilySize
# 0         A/5 21171   7.2500   NaN         2           2
# 1          PC 17599  71.2833   C85         0           2
# 2  STON/O2. 3101282   7.9250   NaN         2           1
# 3            113803  53.1000  C123         2           2
# ...

# %%
features = ['Pclass', 'Sex', 'Age', 'Embarked', 'FamilySize']
X = titanic[features]
y = titanic['Survived']

# %%
X.head()
# Out:
#    Pclass  Sex   Age  Embarked  FamilySize
# 0       3    1  22.0         2           2
# 1       1    0  38.0         0           2
# 2       3    0  26.0         2           1
# 3       1    0  35.0         2           2
# 4       3    1  35.0         2           1

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=45)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
log_r = LogisticRegression()
log_r.fit(X_train, y_train)
y_pred = log_r.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score

accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)
con_mat = confusion_matrix(y_test,y_pred)

print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
print("Confusion Matrix: \n",con_mat)
# Out:
# Accuracy:  0.820627802690583
# Precision:  0.7261904761904762
# Recall:  0.782051282051282
# F1 Score:  0.7530864197530864
# Confusion Matrix:
#  [[122  23]
#  [ 17  61]]

# %%
sb.heatmap(con_mat, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.xticks([0.5,1.5],['Not Survived', 'Survived'])
plt.yticks([0.5,1.5],['Not Survived', 'Survived'])

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

y_prob = log_r.predict_proba(X_test)[:,1]
fpr,tpr, threhsolds = roc_curve(y_test, y_prob)
auc = roc_auc_score(y_test,y_prob)

plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(auc))
plt.plot([0,1],[0,1], '--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

plt.show()

# %%
pclass = int(input("Enter passenger class(1,2,3): "))
sex = int(input("Enter passenger gender(0-female,1-male): "))
age = int(input("Enter passenger age: "))
embarked = int(input("Enter passenger embarked status (0,1,2): "))
family_size = int(input("Enter passenger family size: "))

new_passenger = [[pclass, sex, age, embarked, family_size]]

new_passenger = sc.fit_transform(new_passenger)

prediction = log_r.predict(new_passenger)

if prediction[0] == 0:
  print("Not Survived")
else:
  print("Survived")
# Out:
# Enter passenger class(1,2,3): 1
# Enter passenger gender(0-female,1-male): 0
# Enter passenger age: 33
# Enter passenger embarked status (0,1,2): 2
# Enter passenger family size: 3
# Not Survived
